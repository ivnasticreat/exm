# %% [markdown]
# ## Экзаменационное задание по курсу «Математический анализ и теория вероятностей»

# %% [markdown]
# ## Задание 1
# Найдите производные функций. Подробно распишите решение. Задание должно быть решено без использования Python.

# %% [markdown]
# а) $ y = e^{x \ln(3x + 1)} $

# %% [markdown]
# ***Правила производной сложной функции***
#
# Для функции вида $ y = e^{u} $ производная будет $ y' = e^{u} u' $, где $ u = x \ln(3x + 1) $
# Находим $ u' $
#
# Для $ u = x \ln(3x + 1) $ используем правило произведения:
#
# $
# u' = \frac{d}{dx}(x) \cdot \ln(3x + 1) + x \cdot \frac{d}{dx}\left(\ln(3x + 1)\right)
# $
#
# ***Вычислим*** $ \frac{d}{dx}\left(\ln(3x+1)\right) $
#
# $
# \frac{d}{dx}\left(\ln(3x + 1)\right) = \frac{3}{3x + 1} \quad
# $
#
# ***Таким образом:***
#
# $
# u' = \ln(3x + 1) + x \cdot \frac{3}{3x + 1}
# $
# $
# = \ln(3x + 1) + \frac{3x}{3x + 1}
# $
#
# ***Записываем значение производной***
# $
# y' = e^{x \ln(3x + 1)} \left( \ln(3x + 1) + \frac{3x}{3x + 1} \right)
# $

# %% [markdown]
# б) $y = e^{x^2} \sqrt{x^3 + 4x^2 - 7}$

# %% [markdown]
# ***Правило произведения***
#
# $\frac{d}{dx}(u \cdot v) = u' \cdot v + u \cdot v'$
#
# Здесь:
# $u(x) = e^{x^2}, \quad v(x) = (x^3 + 4x^2 - 7)^{1/2}$
#
# ***Производная*** $ u(x) $:
# $
# u'(x) = \frac{d}{dx} \left(e^{x^2}\right) = e^{x^2} \cdot 2x
# $
#
# ***Производная*** $ v(x) $:
#
# $v'(x) = \frac{d}{dx} \left( (x^3 + 4x^2 - 7)^{1/2} \right)$
#
# $v'(x) = \frac{1}{2}(x^3 + 4x^2 - 7)^{-1/2} \cdot \frac{d}{dx}(x^3 + 4x^2 - 7) = \frac{1}{2}(x^3 + 4x^2 - 7)^{-1/2} \cdot (3x^2 + 8x)
# $
#
# ***Сложим производные***
#
# $y' = \left(e^{x^2} \cdot 2x\right) \cdot (x^3 + 4x^2 - 7)^{1/2} + e^{x^2} \cdot \left[\frac{1}{2}(x^3 + 4x^2 - 7)^{-1/2} \cdot (3x^2 + 8x)\right] $
#
# ***Упростим***
# Вынесем общий множитель $ e^{x^2} $:
#
# $y' = e^{x^2} \left[ 2x(x^3 + 4x^2 - 7)^{1/2} + \frac{(3x^2 + 8x)}{2(x^3 + 4x^2 - 7)^{1/2}} \right]$
#
# **Ответ:**
# $y' = e^{x^2} \left[ \frac{4x^4+16x^3-20x+3x^2}{2(x^3 + 4x^2 - 7)^{1/2}} \right]$

# %% [markdown]
# в) $y = \frac{x \sqrt{1 - x^2}}{1 + x^2}$

# %% [markdown]
# ***Правило производной частного***
#
# Для функции $ y = \frac{u(x)}{v(x)} $, производная задается формулой:
# $
# \frac{d}{dx}\left(\frac{u}{v}\right) = \frac{u'v - uv'}{v^2}
# $
#
# Здесь:
# $
# u(x) = x\sqrt{1-x^2}, \quad v(x) = 1+x^2
# $
#
# ***Найдем*** $ u'(x) $:
#
# Правило произведения: $ u' = u_1' u_2 + u_1 u_2' $, где $ u_1 = x $ и $ u_2 = \sqrt{1-x^2} $
#
# 1. Производная $ u_1 = x $:
# $
# u_1' = 1
# $
#
# 1. Производная $ u_2 = \sqrt{1-x^2} $:
# $
# u_2 = (1-x^2)^{1/2}, \quad u_2' = \frac{1}{2}(1-x^2)^{-1/2} \cdot (-2x) = \frac{-x}{\sqrt{1-x^2}}
# $
#
# Теперь подставим:
# $
# u'(x) = 1 \cdot \sqrt{1-x^2} + x \cdot \frac{-x}{\sqrt{1-x^2}} = \sqrt{1-x^2} - \frac{x^2}{\sqrt{1-x^2}}
# $
#
# Приведем к общему знаменателю:
# $
# u'(x) = \frac{(1-x^2) - x^2}{\sqrt{1-x^2}} = \frac{1-2x^2}{\sqrt{1-x^2}}
# $
#
# ***Найдем*** $ v'(x) $:
# $
# v(x) = 1+x^2, \quad v'(x) = 2x
# $
#
# ***Подставим в формулу производной частного***
#
# $
# y' = \frac{u'v - uv'}{v^2}
# $
#
# $
# y' = \frac{\left(\frac{1-2x^2}{\sqrt{1-x^2}}\right)(1+x^2) - \left(x\sqrt{1-x^2}\right)(2x)}{(1+x^2)^2}
# $
#
# 1. Упростим числитель:
# $
# \frac{(1-2x^2)(1+x^2)}{\sqrt{1-x^2}} - \frac{2x^2\sqrt{1-x^2}}{\sqrt{1-x^2}}
# = \frac{(1-2x^2)(1+x^2) - 2x^2(1-x^2)}{\sqrt{1-x^2}}.
# $
#
# 1. Раскроем скобки:
# $
# (1-2x^2)(1+x^2) = 1 + x^2 - 2x^2 - 2x^4 = 1 - x^2 - 2x^4
# $
#
# $
# -2x^2(1-x^2) = -2x^2 + 2x^4
# $
#
# Итак, числитель:
# $
# 1 - x^2 - 2x^4 - 2x^2 + 2x^4 = 1 - x^2 - 2x^2 = 1 - 3x^2
# $
#
#
# **Ответ:**
# $
# y' = \frac{1 - 3x^2}{\sqrt{1-x^2}(1+x^2)^2}.
# $

# %% [markdown]
# ## Задание 2
# Найдите безусловные экстремумы функции:

# %% [markdown]
# $ u = 3x^3 + y^2 + z^2 +6xy -2z + 1$

# %% [markdown]
# **Решение**
#
# Найдём критические точки. Для этого возьмем частные производные по каждой из переменных и приравняв результаты к 0 решим полученную систему уровнений:
#
#
# $
# \begin{cases}
#     & u'_x = 0 \\
#     & u'_y = 0 \\
#     & u'_z = 0
# \end{cases}
#  =>
# $
# $
# \begin{cases}
#     & 9x^2 +6y = 0 \\
#     & 2y + 6x = 0 \\
#     & 2z - 2 = 0
# \end{cases}
#  => $
# $
# \begin{cases}
#     & 9x^2 + 6y = 0 \\
#     & 18x + 6y = 0 \\
#     & 2z - 2 = 0
# \end{cases}
#  =>$
# $
# \begin{cases}
#     & 9x^2 - 18x = 0 \\
#     & 18x + 6y = 0 \\
#     & 2z - 2 = 0
# \end{cases}
#  =>$
# $
# \begin{cases}
#     & x^2 - 2x = 0 \\
#     & 3x + y = 0 \\
#     & z = 1
# \end{cases}
#  =>$
#
#  <br>
# $
# \begin{cases}
#     & x(x - 2) = 0 \\
#     & y = -3x \\
#     & z = 1
# \end{cases}
#  =>$
# $
# \begin{align*}
#     & x_1 = 0; x_2 = 2 \\
#     & y_1 = 0; y_2 = -6\\
#     & z_1 = 1; z_2 = 1
# \end{align*}
#  =>$
# $
# \begin{align*}
#     & (0, 0, 1)\\
#     & (2, -6, 1)
# \end{align*}
#  $
# <br>
# Определим типы точек экстремума:
#
# Для этого возьмем вторые производные и сформируем матрицы Гессе для каждой из точек
#
# $
# \begin{align*}
#     & u''_{xx} = (9x^2 +6y)'_x =18x \\
#     & u''_{yy} = (2y + 6x)'_y = 2 \\
#     & u''_{zz} = (2z - 2)'_z = 2 \\
#     & u''_{xy} = u''_{yx} = (9x^2 +6y)'_y = 6 \\
#     & u''_{xz} = u''_{zx} = (9x^2 +6y)'_z = 0 \\
#     & u''_{yz} = u''_{zy} = (2y + 6x)'_z = 0
# \end{align*}
#  => $
# $
# H =
# \begin{pmatrix}
#     18x & 6 & 0 \\
#     6 & 2 & 0 \\
#     0 & 0 & 2
# \end{pmatrix}
#  =>
# $
# $
#             H_{(0, 0, 1)} =
# \begin{pmatrix}
#     0 & 6 & 0 \\
#     6 & 2 & 0 \\
#     0 & 0 & 2
# \end{pmatrix}
#  $
#  $
#         H_{(2, -6, 1)} =
# \begin{pmatrix}
#     36 & 6 & 0 \\
#     6 & 2 & 0 \\
#     0 & 0 & 2
# \end{pmatrix}
# $
#
#
#
# Рассчитаем определители матриц, и сделаем выводы относительно типов точек экстремума
#
#
#
# \begin{align*}
#     & {det}(H_{(0, 0, 1)})  = 0 \cdot
# \begin{vmatrix}
# 2 & 0 \\
# 0 & 2
# \end{vmatrix}
# - 6 \cdot
# \begin{vmatrix}
# 6 & 0 \\
# 0 & 2
# \end{vmatrix}
# + 0 \cdot
# \begin{vmatrix}
# 6 & 2 \\
# 0 & 0
# \end{vmatrix}
# = 0 \cdot (2 \cdot 2 − 0 \cdot 0) - 6 \cdot (6 \cdot 2 - 0 \cdot 2) + 0 \cdot (6 \cdot 0 - 0 \cdot 2) = -72
# => \text{точка (0, 0, 1) является седловой т.к. определитель отрицателеный}
# \\
#     & {det}(H_{(2, -6, 1)})  = 36 \cdot
# \begin{vmatrix}
# 2 & 0 \\
# 0 & 2
# \end{vmatrix}
# - 6 \cdot
# \begin{vmatrix}
# 6 & 0 \\
# 0 & 2
# \end{vmatrix}
# + 0 \cdot
# \begin{vmatrix}
# 6 & 2 \\
# 0 & 0
# \end{vmatrix}
# = 36 \cdot (2 \cdot 2 − 0 \cdot 0) - 6 \cdot (6 \cdot 2 - 0 \cdot 2) + 0 \cdot (6 \cdot 0 - 0 \cdot 2) = 72
# => \text{точка (2, -6, 1) является минимумом т.к. определитель положительный}
# \end{align*}

# %% [markdown]
# ## Задание 3
#
# Найдите условный экстремум функции: $z=e^{-х-y}$
#
# Если задано следующее условие: $\frac{x^2}{4} + y^2 = 5$

# %% [markdown]
# Используем метод множителей Лагранжа
#
# ***Определяем функцию Лагранжа:***
#
# $
# \mathcal{L}(x, y, \lambda) = e^{-x-y} + \lambda \left( \frac{x^2}{4} + y^2 - 5 \right)
# $
#
# Нам нужно найти критические точки, решив систему уравнений, полученную при вычислении частных производных от $\mathcal{L}$
#
# 1. Вычисляем частные производные:
#
# $
# \frac{\partial \mathcal{L}}{\partial x} = -e^{-x-y} + \lambda \cdot \frac{x}{2} = 0
# $
#
# $
# \frac{\partial \mathcal{L}}{\partial y} = -e^{-x-y} + 2\lambda y = 0
# $
#
# $
# \frac{\partial \mathcal{L}}{\partial \lambda} = \frac{x^2}{4} + y^2 - 5 = 0
# $
#
# 2. Решим систему уравнени:
#
# Из 1 уравнения:
#
# $
# \lambda = \frac{2 e^{-x-y}}{x}
# $
#
# Из 2:
#
# $
# \lambda = \frac{e^{-x-y}}{2y}
# $
#
# Приравниваем выражения для $\lambda$:
#
# $
# \frac{2 e^{-x-y}}{x} = \frac{e^{-x-y}}{2y}
# $
#
# Упрощаем:
#
# $
# \frac{2}{x} = \frac{1}{2y} \quad \Rightarrow \quad 4y = x
# $
#
# Заменяем $x = 4y$ в ограничении:
#
# $
# \frac{(4y)^2}{4} + y^2 = 5
# $
#
# $
# \frac{16y^2}{4} + y^2 = 5 \quad \Rightarrow \quad 4y^2 + y^2 = 5
# $
#
# $
# 5y^2 = 5 \quad \Rightarrow \quad y^2 = 1 \quad \Rightarrow \quad y = \pm 1
# $
#
# Для $y = 1$, $x = 4 \times 1 = 4$.
#
# Для $y = -1$, $x = 4 \times (-1) = -4$.
#
# Подставим точки в $z = e^{-x-y}$:
#
# Для $(x, y) = (4, 1)$:
# $
# z = e^{-4-1} = e^{-5}
# $
#
# Для $(x, y) = (-4, -1)$:
# $
# z = e^{-(-4) - (-1)} = e^{5}
# $
#
# Ответ: минимум в точке (4,1) со значением $e^{-5}$, максимум в точке (-4, -1) со значением $e^{5}$.

# %% [markdown]
# ## Задание 4
# Вам предоставлены данные о людях с наличием или отсутствием заболевания:

# %% [markdown]
# Признаки:
# - Age — возрастная группа.
# - Test — позитивный или негативный тест на заболевание.
# - Status — целевая переменная, есть инфекция или нет.
#
# Необходимо реализовать алгоритм Наивного Байеса для решения задачи классификации. Обязательно оцените качество полученного результата по итогу.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Пример данных
df = pd.read_csv('exam.csv')

# Преобразование категориальных переменных в числовые
df['Age_Group'] = df['Age_Group'].astype('category').cat.codes
df['Test'] = df['Test'].astype('category').cat.codes
df['Status'] = df['Status'].astype('category').cat.codes

# Разделение данных на признаки и целевую переменную
X = df[['Age_Group', 'Test']]
y = df['Status']

# Разделение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Обучение модели Наивного Байеса
model = GaussianNB()
model.fit(X_train, y_train)

# Прогнозирование на тестовой выборке
y_pred = model.predict(X_test)

# Оценка качества модели
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)

# %%
Accuracy: 0.67
Confusion Matrix:
[[18 25]
 [ 3 38]]
Classification Report:
              precision    recall  f1-score   support

           0       0.86      0.42      0.56        43
           1       0.60      0.93      0.73        41

    accuracy                           0.67        84
   macro avg       0.73      0.67      0.65        84
weighted avg       0.73      0.67      0.64        84

# %% [markdown]
# # Задание 5
# Дана функция:
#
# $$f(x)=x^{4}+3 x^{3}-12 x^{2}+7 x-2$$
# Оптимизируйте её с помощью метода Ньютона, используя язык программирования Python.
#
# За начальную точку возьмите х = 10, необходимую точность 0.0001.

# %%
import numpy as np

def f(x):
    return x**4 + 3*x**3 - 12*x**2 + 7*x - 2

# Первая производная
def f_prime(x):
    return 4*x**3 + 9*x**2 - 24*x + 7

# Вторая производная
def f_double_prime(x):
    return 12*x**2 + 18*x - 24

# Метод Ньютона
def newton_method(x0, tolerance):
    x_n = x0
    while True:
        f_prime_val = f_prime(x_n)
        f_double_prime_val = f_double_prime(x_n)
        
        # Проверка на ноль для второй производной
        if f_double_prime_val == 0:
            print("Вторая производная равна нулю. Метод Ньютона не может быть применен.")
            return None
        
        # Обновление x
        x_n1 = x_n - f_prime_val / f_double_prime_val
        
        # Проверка на сходимость
        if abs(x_n1 - x_n) < tolerance:
            break
        
        x_n = x_n1
    
    return x_n

# Начальная точка и точность
initial_x = 10
tolerance = 0.0001

# Запуск метода Ньютона
optimal_x = newton_method(initial_x, tolerance)
print(f"Оптимальное значение x: {optimal_x}")
print(f"Значение функции в оптимальной точке: {f(optimal_x)}")

# %% [markdown]
# # Задание 6
# Дано распределение случайной величины, которая отражает вероятность получения разного количества спам-писем в течение дня:
# ![asset-v1_SkillFactory+MIFIML-1sem+2024+type@asset+block@экз_Математическии__анализ_и_теория_вероятностеи_.png](attachment:5a1a65c5-ed8d-4d5b-9a21-0735386b02bc.png)

# %%
# Данные вероятностей
probab = [0.1, 0.3, 0.1, 0.25, 0.05, 0.05, 0.1]

# Вероятность получения 7 спам-писем
sum_probab = sum(probab)
prob_7 = 1 - sum_probab  # Вероятность для 7 писем
probab.append(prob_7)  # Добавим вероятность 7 писем в список

print(f"Вероятность получения 7 спам-писем: {prob_7:.2f}")

# Математическое ожидание
expected_value = 0
for i in range(len(probab)):
    expected_value += i * probab[i]

print(f"Математическое ожидание: {expected_value:.2f}")

# Найдем дисперсию, но сначала найдем E(X^2)
expected_value_squared = 0
for i in range(len(probab)):
    expected_value_squared += (i ** 2) * probab[i]

# Теперь найдем дисперсию
variance = expected_value_squared - (expected_value ** 2)

print(f"Дисперсия: {variance:.2f}")

# %% [markdown]
# # Задание 7
# За 8 часов рабочего дня в колл-центр поступает в среднем 16 звонков. Найдите вероятность, что за час в колл-центр поступит не более 4 и не менее 2 звонков. Ответ округлите до тысячных. Задание должно быть решено без использования готовых функций Python.

# %%
# Параметр λ
lambda_value = 2

# Функция для вычисления e^(-λ) без использования готовых функций
def exp_neg_lambda(lambda_value):
    e_neg_lambda = 1.0  # Начальное значение для e^(-λ)
    term = 1.0          # Текущий член ряда
    n = 1               # Счетчик для членов ряда
    while n < 100:      # Суммируем первые 100 членов ряда
        term *= -lambda_value / n  # Следующий член ряда
        e_neg_lambda += term
        n += 1
    return e_neg_lambda

# Функция для вычисления k! без использования готовых функций
def factorial(k):
    result = 1
    for i in range(1, k + 1):
        result *= i
    return result

# Функция для вычисления вероятности по распределению Пуассона
def poisson_probability(k, lambda_value):
    e_neg_lambda = exp_neg_lambda(lambda_value)
    return (e_neg_lambda * (lambda_value ** k)) / factorial(k)

# Вычисляем вероятности для k = 2, 3, 4
prob_2 = poisson_probability(2, lambda_value)
prob_3 = poisson_probability(3, lambda_value)
prob_4 = poisson_probability(4, lambda_value)

# Суммируем вероятности
total_probability = prob_2 + prob_3 + prob_4

# Округляем до тысячных
total_probability_rounded = int(total_probability * 1000 + 0.5) / 1000.0

# Выводим результат
print(f"Вероятность, что за час поступит не более 4 и не менее 2 звонков: {total_probability_rounded:.3f}")
